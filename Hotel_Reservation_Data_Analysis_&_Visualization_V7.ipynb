# %% [markdown]
# <a href="https://colab.research.google.com/github/rbhattar07/Python-Projects--Data-Analysis/blob/main/Hotel_Reservation_Data_Analysis_%26_Visualization_V7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-08aa9836-f606-4073-ad67-94a3296cd6e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08aa9836-f606-4073-ad67-94a3296cd6e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls -lha kaggle.json
# Out:
# -rw-r--r-- 1 root root 68 Feb 10 05:08 kaggle.json

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !pwd
# Out:
# /content

# %%
# !kaggle datasets list
# Out:
# ref                                                             title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# ahsan81/hotel-reservations-classification-dataset               Hotel Reservations Dataset                         480KB  2023-01-04 12:50:31          10119        337  1.0
# googleai/musiccaps                                              MusicCaps                                          793KB  2023-01-25 09:25:48           2214        205  0.9411765
# themrityunjaypathak/most-subscribed-1000-youtube-channels       Most Subscribed 1000 Youtube Channels               28KB  2023-01-21 14:42:05           3131         92  1.0
# ...

# %%
# !kaggle datasets download -d ahsan81/hotel-reservations-classification-dataset
# Out:
# ...
#   0% 0.00/480k [00:00<?, ?B/s]
# 100% 480k/480k [00:00<00:00, 127MB/s]

# %%
# !unzip hotel-reservations-classification-dataset.zip
# Out:
# Archive:  hotel-reservations-classification-dataset.zip
#   inflating: Hotel Reservations.csv

# %%
# !pip install opendatasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
import opendatasets as od
import math
import urllib
import math
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
main_df = pd.read_csv('/content/Hotel Reservations.csv')
main_df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %%
main_df.head(10)
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
# 5   INN00006             2               0                     0
# 6   INN00007             2               0                     1
# 7   INN00008             2               0                     1
# 8   INN00009             3               0                     0
# 9   INN00010             2               0                     0
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# ...

# %%
main_df.tail(10)
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 36265   INN36266             2               0                     1
# 36266   INN36267             2               0                     2
# 36267   INN36268             2               0                     1
# 36268   INN36269             1               0                     0
# 36269   INN36270             2               2                     0
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 36265                  3       Meal Plan 1                           0
# ...

# %%
  main_df.sample(10)
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 21785   INN21786             1               0                     2
# 34815   INN34816             3               0                     0
# 20369   INN20370             2               0                     0
# 25753   INN25754             1               0                     0
# 28142   INN28143             1               0                     0
# 22218   INN22219             2               0                     1
# 22224   INN22225             2               0                     0
# 3116    INN03117             2               0                     2
# 10762   INN10763             2               0                     0
# 6921    INN06922             1               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 21785                  0       Meal Plan 1                           0
# ...

# %%
main_df.describe()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  36275.000000    36275.000000          36275.000000       36275.000000
# mean       1.844962        0.105279              0.810724           2.204300
# std        0.518715        0.402648              0.870644           1.410905
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              7.000000          17.000000
#
#        required_car_parking_space     lead_time  arrival_year  arrival_month  \
# count                36275.000000  36275.000000  36275.000000   36275.000000
# mean                     0.030986     85.232557   2017.820427       7.423653
# ...

# %%
main_df.columns
# Out:
# Index(['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
df = main_df.copy()
df = df[['Booking_ID', 'arrival_year', 'arrival_month',
       'arrival_date', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights',
       'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
       'room_type_reserved', 'lead_time', 'market_segment_type', 'repeated_guest',
       'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
       'avg_price_per_room', 'no_of_special_requests', 'booking_status']]

# %%
df['arrival_year'].value_counts()
print('Two years')
# Out:
# Two years

# %%
df['arrival_month'].value_counts()
# Out:
# 10    5317
# 9     4611
# 8     3813
# 6     3203
# 12    3021
# 11    2980
# 7     2920
# 4     2736
# 5     2598
# 3     2358
# 2     1704
# 1     1014
# Name: arrival_month, dtype: int64

# %%
df['arrival_date'].value_counts()
# Out:
# 13    1358
# 17    1345
# 2     1331
# 4     1327
# 19    1327
# 16    1306
# 20    1281
# 15    1273
# 6     1273
# 18    1260
# 14    1242
# 30    1216
# 12    1204
# 8     1198
# 29    1190
# 21    1158
# 5     1154
# 26    1146
# 25    1146
# 1     1133
# 9     1130
# 28    1129
# 7     1110
# 24    1103
# 11    1098
# 3     1098
# 10    1089
# 27    1059
# 22    1023
# 23     990
# 31     578
# Name: arrival_date, dtype: int64

# %%
df['no_of_adults'].value_counts()
# Out:
# 2    26108
# 1     7695
# 3     2317
# 0      139
# 4       16
# Name: no_of_adults, dtype: int64

# %%
df['no_of_children'].value_counts()
# Out:
# 0     33577
# 1      1618
# 2      1058
# 3        19
# 9         2
# 10        1
# Name: no_of_children, dtype: int64

# %%
df['no_of_weekend_nights'].value_counts()
# Out:
# 0    16872
# 1     9995
# 2     9071
# 3      153
# 4      129
# 5       34
# 6       20
# 7        1
# Name: no_of_weekend_nights, dtype: int64

# %%
df['no_of_week_nights'].value_counts()
# Out:
# 2     11444
# 1      9488
# 3      7839
# 4      2990
# 0      2387
# 5      1614
# 6       189
# 7       113
# 10       62
# 8        62
# 9        34
# 11       17
# 15       10
# 12        9
# 14        7
# 13        5
# 17        3
# 16        2
# Name: no_of_week_nights, dtype: int64

# %%
df['type_of_meal_plan'].value_counts()
# Out:
# Meal Plan 1     27835
# Not Selected     5130
# Meal Plan 2      3305
# Meal Plan 3         5
# Name: type_of_meal_plan, dtype: int64

# %%
df['required_car_parking_space'].value_counts()
# Out:
# 0    35151
# 1     1124
# Name: required_car_parking_space, dtype: int64

# %%
df['room_type_reserved'].value_counts()
# Out:
# Room_Type 1    28130
# Room_Type 4     6057
# Room_Type 6      966
# Room_Type 2      692
# Room_Type 5      265
# Room_Type 7      158
# Room_Type 3        7
# Name: room_type_reserved, dtype: int64

# %%
df['lead_time'].value_counts()
# Out:
# 0      1297
# 1      1078
# 2       643
# 3       630
# 4       628
#        ...
# 300       1
# 353       1
# 328       1
# 352       1
# 351       1
# Name: lead_time, Length: 352, dtype: int64

# %%
df['market_segment_type'].value_counts()
# Out:
# Online           23214
# Offline          10528
# Corporate         2017
# Complementary      391
# Aviation           125
# Name: market_segment_type, dtype: int64

# %%
df['repeated_guest'].value_counts()
# Out:
# 0    35345
# 1      930
# Name: repeated_guest, dtype: int64

# %%
df['no_of_previous_cancellations'].value_counts()
# Out:
# 0     35937
# 1       198
# 2        46
# 3        43
# 11       25
# 5        11
# 4        10
# 13        4
# 6         1
# Name: no_of_previous_cancellations, dtype: int64

# %%
df['no_of_previous_bookings_not_canceled'].value_counts()
# Out:
# 0     35463
# 1       228
# 2       112
# 3        80
# 4        65
# 5        60
# 6        36
# 7        24
# 8        23
# 10       19
# 9        19
# 11       15
# 12       12
# 14        9
# 15        8
# 16        7
# 13        7
# 18        6
# 20        6
# 21        6
# 17        6
# 19        6
# 22        6
# 25        3
# 27        3
# 24        3
# 23        3
# 44        2
# 29        2
# 48        2
# 28        2
# 30        2
# 32        2
# 31        2
# 26        2
# 46        1
# 55        1
# 45        1
# 57        1
# 53        1
# 54        1
# 58        1
# 41        1
# 40        1
# 43        1
# 35        1
# 50        1
# 56        1
# 33        1
# 37        1
# 42        1
# 51        1
# 38        1
# 34        1
# 39        1
# 52        1
# 49        1
# 47        1
# 36        1
# Name: no_of_previous_bookings_not_canceled, dtype: int64

# %%
df['avg_price_per_room'].value_counts()
# Out:
# 65.00     848
# 75.00     826
# 90.00     703
# 95.00     669
# 115.00    662
#          ...
# 212.42      1
# 83.48       1
# 70.42       1
# 130.99      1
# 167.80      1
# Name: avg_price_per_room, Length: 3930, dtype: int64

# %%
df['no_of_special_requests'].value_counts()
# Out:
# 0    19777
# 1    11373
# 2     4364
# 3      675
# 4       78
# 5        8
# Name: no_of_special_requests, dtype: int64

# %%
df['booking_status'].value_counts()
# Out:
# Not_Canceled    24390
# Canceled        11885
# Name: booking_status, dtype: int64

# %%
df
# Out:
#       Booking_ID  arrival_year  arrival_month  arrival_date  no_of_adults  \
# 0       INN00001          2017             10             2             2
# 1       INN00002          2018             11             6             2
# 2       INN00003          2018              2            28             1
# 3       INN00004          2018              5            20             2
# 4       INN00005          2018              4            11             2
# ...          ...           ...            ...           ...           ...
# 36270   INN36271          2018              8             3             3
# 36271   INN36272          2018             10            17             2
# 36272   INN36273          2018              7             1             2
# 36273   INN36274          2018              4            21             2
# 36274   INN36275          2018             12            30             2
#
#        no_of_children  no_of_weekend_nights  no_of_week_nights  \
# ...

# %%
df.isnull().sum()
# zero null values
# Out:
# Booking_ID                              0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Booking_ID', 'arrival_year', 'arrival_month', 'arrival_date',
#        'no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'market_segment_type',
#        'repeated_guest', 'no_of_previous_cancellations',
#        'no_of_previous_bookings_not_canceled', 'avg_price_per_room',
#        'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
plt.figure(figsize=(15,12))
sns.heatmap(df.corr(), annot= True, cmap='Blues');
plt.title('Correlation heatmap', fontweight='bold', fontsize=15);
plt.show()

# %%
plt.figure(figsize=(13,8))
plt.hist(df.no_of_adults, bins=4, edgecolor='white');
plt.xlim(0,5);
plt.title('Number of Adult distribution', fontsize=15, fontweight='bold')
plt.xlabel('Number of adults', fontsize=12, fontweight='bold');
plt.ylabel('Number of observations', fontsize=12, fontweight='bold');

# %%
plt.figure(figsize=(13,8))
plt.hist(df.no_of_children, bins=9, edgecolor='white');
plt.xlim(0,9);
plt.title('Number of children distribution', fontsize=15, fontweight='bold')
plt.xlabel('Number of children', fontsize=12, fontweight='bold');
plt.ylabel('Number of observations', fontsize=12, fontweight='bold');

# %%
ys_grp_avg = df.groupby([df.arrival_year], as_index=False).mean().drop(columns= ['arrival_month', 'arrival_date', 'no_of_weekend_nights', 'no_of_week_nights'])

ms2017_grp_avg = df[df['arrival_year'] == 2017].groupby(['arrival_month'], as_index=False).mean().drop(columns=['arrival_date', 'arrival_year', 'no_of_weekend_nights', 'no_of_week_nights'])
ms2018_grp_avg = df[df['arrival_year'] == 2018].groupby(['arrival_month'], as_index=False).mean().drop(columns=['arrival_date', 'arrival_year', 'no_of_weekend_nights', 'no_of_week_nights'])

ds2017_grp_avg = df[df['arrival_year'] == 2017].groupby(['arrival_date'], as_index=False).mean().drop(columns=['arrival_year', 'arrival_month', 'no_of_weekend_nights', 'no_of_week_nights'])
ds2018_grp_avg = df[df['arrival_year'] == 2018].groupby(['arrival_date'], as_index=False).mean().drop(columns=['arrival_year', 'arrival_month', 'no_of_weekend_nights', 'no_of_week_nights'])

# %%
ys_grp_avg
# Out:
#    arrival_year  no_of_adults  no_of_children  required_car_parking_space  \
# 0          2017      1.759902        0.065705                    0.025177
# 1          2018      1.863580        0.113941                    0.032257
#
#    lead_time  repeated_guest  no_of_previous_cancellations  \
# 0  58.886859        0.031778                      0.020264
# 1  90.999026        0.024294                      0.024025
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                              0.054344           90.027898
# 1                              0.175095          106.355537
#
#    no_of_special_requests
# 0                0.530243
# 1                0.639226

# %%
# Calculating the growth of the avg price in the room from 2017 - 2018
print('2017 avg price for 1 month:', 90.027898)
print('2018 avg price for 1 month:', 106.355537)

growth_percent = (90.027898*100)/106.355537
print('the growth is {}%'.format(100- growth_percent))
# Out:
# 2017 avg price for 1 month: 90.027898
# 2018 avg price for 1 month: 106.355537
# the growth is 15.351940726884777%

# %%
ms2017_grp_avg
# Out:
#    arrival_month  no_of_adults  no_of_children  required_car_parking_space  \
# 0              7      1.815427        0.030303                    0.002755
# 1              8      1.856016        0.142998                    0.042406
# 2              9      1.755609        0.047908                    0.011522
# 3             10      1.713539        0.050706                    0.014114
# 4             11      1.636785        0.021638                    0.030912
# 5             12      1.822198        0.088362                    0.058190
#
#     lead_time  repeated_guest  no_of_previous_cancellations  \
# 0  146.977961        0.000000                      0.000000
# 1   42.250493        0.008876                      0.002959
# 2   56.692541        0.023651                      0.015161
# 3   66.251960        0.038683                      0.032933
# 4   34.425039        0.052550                      0.021638
# 5   48.378233        0.054957                      0.029095
#
# ...

# %%
# Understanding the increasing avg price in 2017 on a monthly basis
plt.figure(figsize=(10,8))
plt.bar(x=ms2017_grp_avg.arrival_month, height=ms2017_grp_avg.avg_price_per_room, alpha=0.7);
plt.plot(ms2017_grp_avg.arrival_month, ms2017_grp_avg.avg_price_per_room, color='k', linewidth=3, marker='o', markersize=7, linestyle='dashed');
plt.text(11,100, s= ms2017_grp_avg['avg_price_per_room'].mean(), fontsize=10, fontweight='bold')
plt.title('Avg. price of rooms in 2017', fontsize=15, fontweight='bold');
plt.xlabel('July 2017 - December 2017', fontsize=12, fontweight='bold');
plt.ylabel('Avg. price of per room', fontsize=12, fontweight='bold');

# %%
# Understanding the increasing avg price in 2018 on a monthly basis
plt.figure(figsize=(10,8))
plt.bar(x=ms2018_grp_avg.arrival_month, height=ms2018_grp_avg.avg_price_per_room, alpha=0.7);
plt.plot(ms2018_grp_avg.arrival_month, ms2018_grp_avg.avg_price_per_room, color='k', linewidth=3, marker='o', markersize=7, linestyle='dashed');
plt.text(11,100, s= ms2018_grp_avg['avg_price_per_room'].mean(), fontsize=10, fontweight='bold')
plt.title('Avg. price of rooms in 2018', fontsize=15, fontweight='bold');
plt.xlim(0,13);
plt.xlabel('Jan 2018 - December 2018', fontsize=12, fontweight='bold');
plt.ylabel('Avg. price of per room', fontsize=12, fontweight='bold');

# %%
df['type_of_meal_plan']
# Out:
# 0         Meal Plan 1
# 1        Not Selected
# 2         Meal Plan 1
# 3         Meal Plan 1
# 4        Not Selected
#              ...
# 36270     Meal Plan 1
# 36271     Meal Plan 1
# 36272     Meal Plan 1
# 36273    Not Selected
# 36274     Meal Plan 1
# Name: type_of_meal_plan, Length: 36275, dtype: object

# %%
meal_plan = df['type_of_meal_plan'].value_counts()
meal_plan
# Out:
# Meal Plan 1     27835
# Not Selected     5130
# Meal Plan 2      3305
# Meal Plan 3         5
# Name: type_of_meal_plan, dtype: int64

# %%
x= ['Meal Plan 1', 'No Meal Plan', 'Meal Plan 2', 'Meal Plan 3']
c = ['green', 'orange', 'yellow', 'black']
e = [0,0,0,0.5]
plt.figure(figsize=(8,8));
plt.pie(meal_plan, labels=x, colors=c, startangle=180, explode=e, autopct='%1.2f%%');
plt.title('Meal Plan ratio between 2017-2018', fontsize=15, fontweight='bold');
plt.show();
print('Meal Plan 1 is in huge demand as at 76% which is a very great sign but at the same time meal plan 3 is a huge fail so the focus should go more on meal plan 1')
# Out:
# Meal Plan 1 is in huge demand as at 76% which is a very great sign but at the same time meal plan 3 is a huge fail so the focus should go more on meal plan 1

# %%
df['type_of_meal_plan'].value_counts()
meal_plan_codes = {'Meal Plan 1': 1,
                   'Not Selected': 0,
                   'Meal Plan 2': 2, 
                   'Meal Plan 3': 3}
df['type_of_meal_plan_codes'] = df['type_of_meal_plan'].map(meal_plan_codes)
df
# Out:
#       Booking_ID  arrival_year  arrival_month  arrival_date  no_of_adults  \
# 0       INN00001          2017             10             2             2
# 1       INN00002          2018             11             6             2
# 2       INN00003          2018              2            28             1
# 3       INN00004          2018              5            20             2
# 4       INN00005          2018              4            11             2
# ...          ...           ...            ...           ...           ...
# 36270   INN36271          2018              8             3             3
# 36271   INN36272          2018             10            17             2
# 36272   INN36273          2018              7             1             2
# 36273   INN36274          2018              4            21             2
# 36274   INN36275          2018             12            30             2
#
#        no_of_children  no_of_weekend_nights  no_of_week_nights  \
# ...

# %%
df['room_type_reserved'].value_counts()
room_codes = {'Room_Type 1': 1,
              'Room_Type 4': 4,
              'Room_Type 6': 6,
              'Room_Type 2': 2,
              'Room_Type 5': 5,
              'Room_Type 7': 7,
              'Room_Type 3': 3}
df['room_type_reserved_codes'] = df['room_type_reserved'].map(room_codes)
df[['room_type_reserved', 'room_type_reserved_codes']].value_counts()
# Out:
# room_type_reserved  room_type_reserved_codes
# Room_Type 1         1                           28130
# Room_Type 4         4                            6057
# Room_Type 6         6                             966
# Room_Type 2         2                             692
# Room_Type 5         5                             265
# Room_Type 7         7                             158
# Room_Type 3         3                               7
# dtype: int64

# %%
df['market_segment_type'].value_counts()
ms_codes = {
    'Online':1,
    'Offline':2,
    'Corporate':3,
    'Complementary':4,
    'Aviation':5
}
df['market_segment_type_codes']= df['market_segment_type'].map(ms_codes)
df
# Out:
#       Booking_ID  arrival_year  arrival_month  arrival_date  no_of_adults  \
# 0       INN00001          2017             10             2             2
# 1       INN00002          2018             11             6             2
# 2       INN00003          2018              2            28             1
# 3       INN00004          2018              5            20             2
# 4       INN00005          2018              4            11             2
# ...          ...           ...            ...           ...           ...
# 36270   INN36271          2018              8             3             3
# 36271   INN36272          2018             10            17             2
# 36272   INN36273          2018              7             1             2
# 36273   INN36274          2018              4            21             2
# 36274   INN36275          2018             12            30             2
#
#        no_of_children  no_of_weekend_nights  no_of_week_nights  \
# ...

# %%
df['booking_status'].value_counts()
bs_codes = {
    'Not_Canceled':1,
    'Canceled':0
}
df['booking_status_codes'] = df['booking_status'].map(bs_codes)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 23 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   arrival_year                          36275 non-null  int64
#  2   arrival_month                         36275 non-null  int64
#  3   arrival_date                          36275 non-null  int64
#  4   no_of_adults                          36275 non-null  int64
#  5   no_of_children                        36275 non-null  int64
#  6   no_of_weekend_nights                  36275 non-null  int64
#  7   no_of_week_nights                     36275 non-null  int64
#  8   type_of_meal_plan                     36275 non-null  object
#  9   required_car_parking_space            36275 non-null  int64
#  10  room_type_reserved                    36275 non-null  object
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True, cmap='vlag', vmin=-1, vmax=1);
plt.title('Updated Correlation Matrix', fontweight='bold', fontsize=15);

# %%
udf = df.copy()
udf.drop(columns=['type_of_meal_plan', 'booking_status', 'market_segment_type', 'room_type_reserved'], inplace=True)
udf
# Out:
#       Booking_ID  arrival_year  arrival_month  arrival_date  no_of_adults  \
# 0       INN00001          2017             10             2             2
# 1       INN00002          2018             11             6             2
# 2       INN00003          2018              2            28             1
# 3       INN00004          2018              5            20             2
# 4       INN00005          2018              4            11             2
# ...          ...           ...            ...           ...           ...
# 36270   INN36271          2018              8             3             3
# 36271   INN36272          2018             10            17             2
# 36272   INN36273          2018              7             1             2
# 36273   INN36274          2018              4            21             2
# 36274   INN36275          2018             12            30             2
#
#        no_of_children  no_of_weekend_nights  no_of_week_nights  \
# ...

# %%
# Avg. price per room, number of children, number of adults
plt.figure(figsize=(10,8));
plt.scatter(y=udf.avg_price_per_room,x=udf.no_of_adults, color='green');
plt.scatter(y=udf.avg_price_per_room,x=udf.no_of_children, alpha=0.5, color='yellow');
plt.title('Understanding the relationship between adults&Children and avg. prices', fontsize=15, fontweight='bold');
plt.ylabel('Prices in dollars', fontsize=12, fontweight='bold');
plt.xlabel('Number of adults', fontsize=12, fontweight='bold');
plt.xlim(-1,5);
plt.legend(['Adults', 'Children'], borderpad=2, fontsize=10);

# %%
udf.lead_time.mean()
print('The avg. number of lead days')
# Out:
# The avg. number of lead days

# %%
ms2018_grp_avg.sort_values(by='avg_price_per_room', ascending=False)
# Out:
#     arrival_month  no_of_adults  no_of_children  required_car_parking_space  \
# 8               9      1.889939        0.088791                    0.027684
# 7               8      2.061093        0.219364                    0.063951
# 6               7      2.007039        0.194368                    0.045757
# 4               5      1.840647        0.088530                    0.025019
# 5               6      1.768030        0.065564                    0.022791
# 9              10      1.829025        0.089307                    0.019683
# 3               4      1.892544        0.113670                    0.023757
# 10             11      1.759537        0.059151                    0.026575
# 11             12      1.929288        0.161013                    0.022934
# 2               3      1.879559        0.102629                    0.040288
# 1               2      1.694836        0.100939                    0.031103
# ...

# %%
m2017_max = udf[udf['arrival_year'] == 2017]
m2017_max = m2017_max[m2017_max['arrival_month']==9]
m2017_max = m2017_max.groupby(by=['arrival_date'], as_index=False).mean()

m2017_min = udf[udf['arrival_year'] == 2017]
m2017_min = m2017_min[m2017_min['arrival_month']==11]
m2017_min = m2017_min.groupby(by=['arrival_date'], as_index=False).mean()

# %%
list17_max = m2017_max['avg_price_per_room'].round().astype('int').tolist()
list17_min = m2017_min['avg_price_per_room'].round().astype('int').tolist()

# %%
plt.figure(figsize=(12,7));
plt.plot(m2017_min['avg_price_per_room'], color='red', marker='o');
plt.plot(m2017_max['avg_price_per_room'], color='green', marker='o');
plt.title('30 days of Max & Min avg. rate in 2017', fontsize=15, fontweight='bold');
plt.xlabel('Days', fontsize=12, fontweight='bold');
plt.ylabel('Prices', fontsize=12, fontweight='bold');
plt.legend(['Min', 'Max']);

# %%
m2018_max = udf[udf['arrival_year'] == 2018]
m2018_max = m2018_max[m2018_max['arrival_month']==9]
m2018_max = m2018_max.groupby(by=['arrival_date'], as_index=False).mean()

m2018_min = udf[udf['arrival_year'] == 2018]
m2018_min = m2018_min[m2018_min['arrival_month']==1]
m2018_min = m2018_min.groupby(by=['arrival_date'], as_index=False).mean()

# %%
plt.figure(figsize=(12,7));
plt.plot(m2018_min['avg_price_per_room'], color='red', marker='o');
plt.plot(m2018_max['avg_price_per_room'], color='green', marker='o');
plt.title('30 days of Max & Min avg. rate in 2018', fontsize=15, fontweight='bold');
plt.xlabel('Days', fontsize=12, fontweight='bold');
plt.ylabel('Prices', fontsize=12, fontweight='bold');
plt.legend(['Min', 'Max']);

# %%
mst = df['market_segment_type'].value_counts()
mst
# Out:
# Online           23214
# Offline          10528
# Corporate         2017
# Complementary      391
# Aviation           125
# Name: market_segment_type, dtype: int64

# %%
l1 = ['Online', 'Offline', 'Corporate', 'Complementary', 'Aviation']
c1 = ['Green', 'Orange', 'Yellow', 'grey', 'black']
plt.figure(figsize=(10,8));
plt.title('Distribution of market segement type', fontsize=15, fontweight='bold');
plt.pie(
    mst, 
    colors= c1, 
    labels=l1, 
    explode=[0,0,0.3, 0.4, 0.5], 
    autopct='%1.1f%%',
    shadow=False,
    startangle=360
        );

# %%
df
# Out:
#       Booking_ID  arrival_year  arrival_month  arrival_date  no_of_adults  \
# 0       INN00001          2017             10             2             2
# 1       INN00002          2018             11             6             2
# 2       INN00003          2018              2            28             1
# 3       INN00004          2018              5            20             2
# 4       INN00005          2018              4            11             2
# ...          ...           ...            ...           ...           ...
# 36270   INN36271          2018              8             3             3
# 36271   INN36272          2018             10            17             2
# 36272   INN36273          2018              7             1             2
# 36273   INN36274          2018              4            21             2
# 36274   INN36275          2018             12            30             2
#
#        no_of_children  no_of_weekend_nights  no_of_week_nights  \
# ...

# %%
ms2017_grp_avg
# Out:
#    arrival_month  no_of_adults  no_of_children  required_car_parking_space  \
# 0              7      1.815427        0.030303                    0.002755
# 1              8      1.856016        0.142998                    0.042406
# 2              9      1.755609        0.047908                    0.011522
# 3             10      1.713539        0.050706                    0.014114
# 4             11      1.636785        0.021638                    0.030912
# 5             12      1.822198        0.088362                    0.058190
#
#     lead_time  repeated_guest  no_of_previous_cancellations  \
# 0  146.977961        0.000000                      0.000000
# 1   42.250493        0.008876                      0.002959
# 2   56.692541        0.023651                      0.015161
# 3   66.251960        0.038683                      0.032933
# 4   34.425039        0.052550                      0.021638
# 5   48.378233        0.054957                      0.029095
#
# ...

# %%
ms2018_grp_avg
# Out:
#     arrival_month  no_of_adults  no_of_children  required_car_parking_space  \
# 0               1      1.628205        0.071992                    0.053254
# 1               2      1.694836        0.100939                    0.031103
# 2               3      1.879559        0.102629                    0.040288
# 3               4      1.892544        0.113670                    0.023757
# 4               5      1.840647        0.088530                    0.025019
# 5               6      1.768030        0.065564                    0.022791
# 6               7      2.007039        0.194368                    0.045757
# 7               8      2.061093        0.219364                    0.063951
# 8               9      1.889939        0.088791                    0.027684
# 9              10      1.829025        0.089307                    0.019683
# 10             11      1.759537        0.059151                    0.026575
# ...

# %%
df.columns
# Out:
# Index(['Booking_ID', 'arrival_year', 'arrival_month', 'arrival_date',
#        'no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'market_segment_type',
#        'repeated_guest', 'no_of_previous_cancellations',
#        'no_of_previous_bookings_not_canceled', 'avg_price_per_room',
#        'no_of_special_requests', 'booking_status', 'type_of_meal_plan_codes',
#        'room_type_reserved_codes', 'market_segment_type_codes',
#        'booking_status_codes'],
#       dtype='object')

# %%
m2017_min
# Out:
#     arrival_date  arrival_year  arrival_month  no_of_adults  no_of_children  \
# 0              1        2017.0           11.0      1.840000        0.120000
# 1              2        2017.0           11.0      1.782609        0.000000
# 2              3        2017.0           11.0      1.833333        0.000000
# 3              4        2017.0           11.0      1.730769        0.076923
# 4              5        2017.0           11.0      1.655172        0.000000
# 5              6        2017.0           11.0      1.850000        0.000000
# 6              7        2017.0           11.0      1.916667        0.000000
# 7              8        2017.0           11.0      1.800000        0.000000
# 8              9        2017.0           11.0      1.666667        0.095238
# 9             10        2017.0           11.0      1.636364        0.000000
# 10            11        2017.0           11.0      1.560000        0.080000
# ...

# %%
m2017_max
# Out:
#     arrival_date  arrival_year  arrival_month  no_of_adults  no_of_children  \
# 0              1        2017.0            9.0      1.843750        0.281250
# 1              2        2017.0            9.0      1.774194        0.032258
# 2              3        2017.0            9.0      1.942857        0.257143
# 3              4        2017.0            9.0      1.587302        0.023810
# 4              5        2017.0            9.0      1.809524        0.166667
# 5              6        2017.0            9.0      1.846154        0.000000
# 6              7        2017.0            9.0      1.641509        0.113208
# 7              8        2017.0            9.0      1.750000        0.100000
# 8              9        2017.0            9.0      1.662791        0.046512
# 9             10        2017.0            9.0      1.800000        0.033333
# 10            11        2017.0            9.0      1.818182        0.000000
# ...

# %%
plt.figure(figsize=(10,8), facecolor='grey', edgecolor='white');
plt.title('Arrival percentage as per year', fontsize=20, fontweight='bold');
plt.pie(udf.arrival_year.value_counts(),
        colors=['green', 'yellow'],
        labels=['Year 2018', 'Year 2017'],
        textprops={'fontweight':'bold', 
                   'fontsize':12},
        explode=(0,.2), autopct= '%0.2f%%');

# So, in conclusion it is safe to say that year 2017 constitutes 1/5th of the data which is helpful in order to understand the changes from 2017 to 2018, and also understand the changing in trends and plans from the yearly gap.

# %%
# everyday data 
df2017 = udf[udf['arrival_year']==2017]
df2018 = udf[udf['arrival_year']==2018]

df2017.drop(columns=['Booking_ID', 'arrival_year'], inplace=True)
df2017

df2018.drop(columns=['Booking_ID', 'arrival_year'], inplace=True)
df2018
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        arrival_month  arrival_date  no_of_adults  no_of_children  \
# 1                 11             6             2               0
# 2                  2            28             1               0
# 3                  5            20             2               0
# 4                  4            11             2               0
# 5                  9            13             2               0
# ...              ...           ...           ...             ...
# 36270              8             3             3               0
# 36271             10            17             2               0
# ...

# %%
x= np.array(m2017_min.avg_price_per_room)
y= np.array(m2017_max.avg_price_per_room)
y
# Out:
# array([ 92.8709375 ,  80.95193548, 113.62028571,  96.03746032,
#        106.37190476,  84.56307692, 111.4       ,  99.091     ,
#         97.47151163, 101.48633333, 105.92060606, 104.63333333,
#        104.44555556,  91.1       , 100.02188679, 106.65902439,
#         82.00759036, 101.81422886, 121.05285714,  95.60467532,
#         86.50694737, 104.91854545, 178.98978723, 107.08576271,
#        137.52      , 163.76133333,  95.434     , 113.63375   ,
#         75.69651163, 108.66550459])

# %%
plt.figure(figsize=(15,10));
plt.title('Avg price of rooms in the month of November', fontsize=15, fontweight='bold');
plt.bar(x=m2017_min.arrival_date, height=m2017_min.avg_price_per_room);
plt.plot(m2017_min.avg_price_per_room, marker='*', linestyle='--', ms=10, c='black');
plt.ylim(0,90);
plt.xlabel('Days of the month of November', fontsize=12, fontweight='bold');
plt.ylabel('Avg. Price per day', fontsize=12, fontweight='bold');

# %%
plt.figure(figsize=(15,10));
plt.title('Avg price of rooms in the month of September', fontsize=15, fontweight='bold');
plt.bar(x=m2017_max.arrival_date, height=m2017_max.avg_price_per_room);
plt.plot(m2017_max.avg_price_per_room, marker='*', linestyle='--', ms=10, c='black');
plt.ylim(0,200);
plt.xlabel('Days of the month of September', fontsize=12, fontweight='bold');
plt.ylabel('Avg. Price per day', fontsize=12, fontweight='bold');

# %%
plt.figure(figsize=(15,10));
plt.title('Avg price of rooms in the month of January', fontsize=15, fontweight='bold');
plt.bar(x=m2018_min.arrival_date, height=m2018_min.avg_price_per_room);
plt.plot(m2018_min.avg_price_per_room, marker='*', linestyle='--', ms=10, c='black');
plt.ylim(0,110);
plt.xlabel('Days of the month of January', fontsize=12, fontweight='bold');
plt.ylabel('Avg. Price per day', fontsize=12, fontweight='bold');

# %%
plt.figure(figsize=(15,10));
plt.title('Avg price of rooms in the month of September', fontsize=15, fontweight='bold');
plt.bar(x=m2018_max.arrival_date, height=m2018_max.avg_price_per_room);
plt.plot(m2018_max.avg_price_per_room, marker='*', linestyle='--', ms=10, c='black');
plt.ylim(0,160);
plt.xlabel('Days of the month of September', fontsize=12, fontweight='bold');
plt.ylabel('Avg. Price per day', fontsize=12, fontweight='bold');
